# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
## I was not entirely sure what I was supposed to do here
## so I used the capitalize() function on cinderella
## this did change the item in the list

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
def good():
    return ["Harry", "Ron", "Hermione"]
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number
count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        bre
get_odds()
# Out:
# <generator object get_odds at 0x000001E671DB1540>
